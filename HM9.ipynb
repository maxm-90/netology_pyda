# %% [markdown]
# Задание 1
# Напишите функцию date_range, которая возвращает список дней между датами start_date и end_date. Даты должны вводиться в формате YYYY-MM-DD.

# %%
import datetime

# %%
from datetime import datetime

# %%
from datetime import timedelta

# %%
def date_range(start_date, end_date):
    start_date = datetime.strptime(start_date,'%Y-%m-%d')
    end_date = datetime.strptime(end_date,'%Y-%m-%d')
    day = start_date
    days_list = []
    while end_date - timedelta(days=1) > day >= start_date:
        day = day + timedelta(days=1)
        days_list.append(day.strftime('%Y-%m-%d'))
    return days_list

# %%
date_range('2019-9-1', '2019-9-5')
# Out:
# ['2019-09-02', '2019-09-03', '2019-09-04']

# %% [markdown]
# Задание 2
# Дополните функцию из первого задания проверкой на корректность дат. В случае неверного формата или если start_date > end_date должен возвращаться пустой список.

# %%
def date_range(start_date, end_date):
    start_date = datetime.strptime(start_date,'%Y-%m-%d')
    end_date = datetime.strptime(end_date,'%Y-%m-%d')
    day = start_date
    days_list = []
    if start_date > end_date:
        return days_list
    else:
        while end_date - timedelta(days=1) > day >= start_date:
            day = day + timedelta(days=1)
            days_list.append(day.strftime('%Y-%m-%d'))
        return days_list

# %%
date_range('2019-9-1', '2019-9-5')
# Out:
# ['2019-09-02', '2019-09-03', '2019-09-04']

# %% [markdown]
# Задание 3
# Дан поток дат в формате YYYY-MM-DD, в которых встречаются некорректные значения:
# stream = [‘2018-04-02’, ‘2018-02-29’, ‘2018-19-02’]
# Напишите функцию, которая проверяет эти даты на корректность. Т. е. для каждой даты возвращает True (дата корректна) или False (некорректная дата).

# %%
def check_date(stream):
    result = {}
    for date in stream:
        if int(date[5:7]) > 12:
            result.setdefault(date, False)
        else: result.setdefault(date, True)
    return result

# %%
stream = ['2018-04-02', '2018-02-29', '2018-19-02']

# %%
check_date(stream)
# Out:
# {'2018-04-02': True, '2018-02-29': True, '2018-19-02': False}

# %% [markdown]
# Задание 5
# В последнем примере поиска по словарю мы использовали 3 столбца. Напишите функцию, которая формирует словарь для поиска по n столбцам.

# %%
def dict_(columns):
    stats_dict = {}
    with open('stats.csv') as f:
        for line in f:
            line = line.strip().split(',')
            stats_dict[tuple(line[:columns])] = line[3]
    return stats_dict

# %%
line_to_find = ('20', '20552', '3')

# %%
dict_(2)
# Out:
# {('14', '26376'): '13301',
#  ('12', '7316'): '19329',
#  ('28', '2803'): '87381',
#  ('25', '22022'): '94036',
#  ('20', '13883'): '50722',
#  ('14', '21304'): '55449',
#  ('22', '2029'): '12482',
#  ('4', '7384'): '22408',
#  ('24', '20136'): '45396',
#  ('11', '11438'): '88147',
#  ('11', '5131'): '60699',
#  ('26', '2593'): '69093',
#  ('7', '2334'): '21867',
#  ('9', '17428'): '49859',
#  ('1', '21434'): '12730',
#  ('17', '13038'): '102232',
#  ('18', '9915'): '40854',
#  ('13', '17633'): '20050',
#  ('31', '15800'): '68171',
#  ('24', '3922'): '79332',
#  ('17', '2776'): '50128',
#  ('2', '26861'): '24767',
#  ('4', '9841'): '76355',
#  ('26', '12500'): '47262',
#  ('2', '4749'): '6879',
#  ('5', '26813'): '98523',
#  ('22', '12130'): '54395',
#  ('17', '6578'): '84381',
#  ('25', '28140'): '101752',
#  ('7', '20838'): '91626',
#  ('24', '4075'): '51524',
#  ('1', '15432'): '75537',
#  ('9', '1116'): '39499',
#  ('19', '17270'): '63548',
#  ('28', '4670'): '98783',
# ...
